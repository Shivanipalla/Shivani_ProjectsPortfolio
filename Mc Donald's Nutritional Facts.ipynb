# %%
import pandas as pd
import numpy as np
import seaborn as sns
menu = pd.read_csv(r'C:\Users\avina\Documents\My Docs\Datacamp Python course\datasets\menu.csv')
print(menu.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
menu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
menu["Calories"].value_counts()
# Out:
# 0      16
# 340    10
# 430    10
# 280     9
# 250     8
#        ..
# 740     1
# 760     1
# 930     1
# 810     1
# 650     1
# Name: Calories, Length: 78, dtype: int64

# %%
print(menu[menu["Calories"]==0])
# Out:
#          Category                     Item  Serving Size  Calories  \
# 114     Beverages        Diet Coke (Small)  16 fl oz cup         0
# 115     Beverages       Diet Coke (Medium)  21 fl oz cup         0
# 116     Beverages        Diet Coke (Large)  30 fl oz cup         0
# 117     Beverages        Diet Coke (Child)  12 fl oz cup         0
# 122     Beverages   Diet Dr Pepper (Small)  16 fl oz cup         0
# 123     Beverages  Diet Dr Pepper (Medium)  21 fl oz cup         0
# 124     Beverages   Diet Dr Pepper (Large)  30 fl oz cup         0
# 125     Beverages   Diet Dr Pepper (Child)  12 fl oz cup         0
# 136     Beverages      Dasani Water Bottle    16.9 fl oz         0
# 137  Coffee & Tea         Iced Tea (Small)  16 fl oz cup         0
# 138  Coffee & Tea        Iced Tea (Medium)  21 fl oz cup         0
# 139  Coffee & Tea         Iced Tea (Large)  30 fl oz cup         0
# 140  Coffee & Tea         Iced Tea (Child)  12 fl oz cup         0
# ...

# %%
menu.set_index("Item")
# Out:
#                                                              Category  \
# Item
# Egg McMuffin                                                Breakfast
# Egg White Delight                                           Breakfast
# Sausage McMuffin                                            Breakfast
# Sausage McMuffin with Egg                                   Breakfast
# Sausage McMuffin with Egg Whites                            Breakfast
# ...                                                               ...
# McFlurry with Oreo Cookies (Small)                 Smoothies & Shakes
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
#
#                                                       Serving Size  Calories  \
# Item
# ...

# %%
zero_calorie_items=menu[menu["Calories"]==0]

# %%
print(zero_calorie_items)
# Out:
#          Category                     Item  Serving Size  Calories  \
# 114     Beverages        Diet Coke (Small)  16 fl oz cup         0
# 115     Beverages       Diet Coke (Medium)  21 fl oz cup         0
# 116     Beverages        Diet Coke (Large)  30 fl oz cup         0
# 117     Beverages        Diet Coke (Child)  12 fl oz cup         0
# 122     Beverages   Diet Dr Pepper (Small)  16 fl oz cup         0
# 123     Beverages  Diet Dr Pepper (Medium)  21 fl oz cup         0
# 124     Beverages   Diet Dr Pepper (Large)  30 fl oz cup         0
# 125     Beverages   Diet Dr Pepper (Child)  12 fl oz cup         0
# 136     Beverages      Dasani Water Bottle    16.9 fl oz         0
# 137  Coffee & Tea         Iced Tea (Small)  16 fl oz cup         0
# 138  Coffee & Tea        Iced Tea (Medium)  21 fl oz cup         0
# 139  Coffee & Tea         Iced Tea (Large)  30 fl oz cup         0
# 140  Coffee & Tea         Iced Tea (Child)  12 fl oz cup         0
# ...

# %%
menu["Item"].nunique()
# Out:
# 260

# %%
ax = sns.barplot(y='Category',x='Total Fat',data=menu)
sns.set(rc={"figure.figsize":(8, 8)})

# %%
example = menu[menu["Category"]=='Beef & Pork']

# %%
example
# Out:
#        Category                                       Item    Serving Size  \
# 42  Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 43  Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 44  Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 45  Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 46  Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# 47  Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 48  Beef & Pork                                  Hamburger   3.5 oz (98 g)
# 49  Beef & Pork                               Cheeseburger    4 oz (113 g)
# 50  Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 51  Beef & Pork                     Bacon Clubhouse Burger  9.5 oz (270 g)
# 52  Beef & Pork                                   McDouble  5.2 oz (147 g)
# ...

# %%
#plot_order= example.groupby('Item')['Total Fat'].sort_values(ascending = False).index.values
ax = sns.barplot(x='Total Fat',y='Item',data=example, order = example.sort_values('Total Fat',ascending=False).Item)
sns.set(rc={"figure.figsize":(8, 8)})

# %%
Breakfast_menu = menu[menu["Category"]=='Breakfast']

# %%
Breakfast_menu_top5fatfoods = Breakfast_menu.sort_values(by='Total Fat',ascending = False).head(5)

# %%
ax = sns.barplot(x='Total Fat',y='Item',data=Breakfast_menu_top5fatfoods)
sns.set(rc={"figure.figsize":(8, 8)})

# %%
ax = sns.barplot(y='Category',x='Calories',data=menu)
sns.set(rc={"figure.figsize":(15, 35)})

# %%
top_calorie_item = menu[menu['Category']=='Chicken & Fish'].sort_values(by='Calories', ascending=False).head(1)

# %%
top_calorie_item
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %%
t = menu[menu['Calories']>=1880]

# %%
t
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]
